# %%
import requests

# %%
import requests

url = "https://api.sofascore.com/api/v1/event/15219076"

r = requests.get(url, timeout=10)
print(r.status_code)
print(r.text)
# Out:
# 403
# {"error": {"code": 403, "reason": "Forbidden" }}

# %%
response.status_code
# Out:
# 403

# %%
import requests

print(
    requests.get(
        "https://api.sofascore.com/api/v1/sport/football/events/live"
    ).status_code
)
# Out:
# 403
