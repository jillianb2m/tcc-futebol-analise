# %% [markdown]
# # Processing Classification - Cancer

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import plotly.express as px
import seaborn as sns

# %% [markdown]
# ## Load file
# file separator " , "
#
# enconding "iso-8859-1"

# %%
dataframe = pd.read_csv('/content/drive/MyDrive/curso_ML/Treinamento/Classificacao/Desafio/Database/data_cancer.csv', sep = ',', encoding = 'iso-8859-1')

# %%
dataframe.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
dataframe.shape
# Out:
# (569, 33)

# %% [markdown]
# ## Check columns

# %%
dataframe.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
dataframe.isnull().sum() ## remove "Unnamed" column
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# Remove "Unnamed" column which has 569 null values
# remove also "id" column which has only identity values
df2 = dataframe.iloc[:, 1:-1]

# %%
# After removing df2 has 32 columns
df2.shape
# Out:
# (569, 31)

# %%
# data types identified
df2.dtypes
# Out:
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# ...

# %%
df2.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# ### Dashboards

# %%
px.pie(df2, 'diagnosis', width=500, height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
##threshold_value = 0.25
##filtered_df = df2[df2['concavity_mean'] > threshold_value]
filtered_df = df2
sns.histplot(filtered_df, x = 'radius_mean', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='radius_mean', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'perimeter_mean', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='perimeter_mean', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'smoothness_mean', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='smoothness_mean', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'texture_mean', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='texture_mean', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'symmetry_mean', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='symmetry_mean', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'smoothness_worst', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='smoothness_worst', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'texture_worst', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='texture_worst', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'fractal_dimension_mean', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='fractal_dimension_mean', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'radius_worst', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='radius_worst', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'area_mean', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='area_mean', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'concave points_mean', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='concave points_mean', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'compactness_mean', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='compactness_mean', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'concave points_se', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='concave points_se', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'symmetry_worst', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='symmetry_worst', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'texture_se', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='texture_se', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'compactness_worst', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='compactness_worst', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'smoothness_se', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='smoothness_se', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'perimeter_worst', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='perimeter_worst', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'concave points_worst', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='concave points_worst', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'compactness_se', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='compactness_se', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'fractal_dimension_worst', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='fractal_dimension_worst', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'symmetry_se', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='symmetry_se', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'concavity_mean', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='concavity_mean', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'concavity_worst', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='concavity_worst', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'area_worst', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='area_worst', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'perimeter_se', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='perimeter_se', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'concavity_se', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='concavity_se', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'fractal_dimension_se', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='fractal_dimension_se', ylabel='Count'>

# %%
sns.histplot(filtered_df, x = 'radius_se', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='radius_se', ylabel='Count'>

# %% [markdown]
# ### Candidate to remove

# %%
sns.histplot(df2, x = 'area_se', bins=30, color='green', kde=True, stat='count')
# Out:
# <Axes: xlabel='area_se', ylabel='Count'>

# %%
filtered_df.shape
# Out:
# (569, 31)

# %%
columns_to_remove = ['area_se', 'radius_se', 'fractal_dimension_se', 'concavity_se', 'perimeter_se', 'area_worst', 'concavity_worst', 'symmetry_se', 'compactness_se', 'smoothness_se']
df3 = df2.drop(columns=columns_to_remove)

# %%
df3.shape
# Out:
# (569, 21)

# %%
df3.to_csv('cancer_processed.csv', sep=';', encoding='utf-8', index=False)
